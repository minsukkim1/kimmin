# %% [markdown]
# ###  1. 다음 6 개의 Expression에 대해 Evaluation 결과 값을 출력하고, 해당 결과가 나온 이유에 대해 설명하시오
#      1. 1 and 2 and 3 and 4
#      2. 1 or 2 or 3 or 4
#      3. 1 and 2 or 3 and 4
#      4. (1 and 2) or (3 and 4)
#      5. 1 or 2 and 3 or 4
#      6. (1 or 2) and (3 or 4)

# %%
print(1 and 2 and 3 and 4)
print( 1 or 2 or 3 or 4)
print(1 and 2 or 3 and 4)
print((1 and 2) or (3 and 4))
print(1 or 2 and 3 or 4)
print((1 or 2) and (3 or 4))
# Out:
# 4
# 1
# 2
# 2
# 1
# 3

# %% [markdown]
# 1. 1 and 2 and 3 and 4
#      - and연산자의 경우 큰 값을 출력하므로 모든 값이 and이므로 가장 큰 값인 4가 출력된다.
# 2. 1 or 2 or 3 or 4
#      - or연산자의 경우 작은 값을 출력하므로 모든 값이 or이므로 가장 작은 값인 1이 출력된다.
# 3. 1 and 2 or 3 and 4
#      - and와 or의 특성을 이용해 3 and 4는 4,2 or 4 는 2, 1 and 2는 1 이므로 출력값은 2가 출력된다.
# 4. (1 and 2) or (3 and 4)
#      - 1 and 2 는 2, 3 and 4는 4, 2 or 4는 2이므로 출력값은 2가 출력된다.
# 5. 1 or 2 and 3 or 4
#      - 3 or 4는 3, 2 and 3은 3, 1 or 3은 1이므로 1이 출력된다.
# 6. (1 or 2) and (3 or 4)
#      - 1 or 2는 1, 3 or 4은 3, 1 and 3은 3이므로 3이 출력된다.

# %% [markdown]
# ### 2. 경로에 해당하는 문자열 1개를 입력 받아 그 안에 디렉토리 경로명과 파일명을 분리하여 리스트로 반환하는 함수 div_path(s)를 작성하시오.
#  - 인자로 전달하는 문자열은 경로만 들어간다고 가정한다.
#  - 각 디렉토리와 파일을 구분하는 문자는 '/'로 가정한다.
#  - 반환하는 리스트의 첫번째 원소는 디렉토리이고 두번째 원소는 파일명이다.
#  - 다음과 같은 실행 및 출력 결과가 도출되어야 한다.
#      - div_path('/usr/local/bin/python')
#          - ['/usr/local/bin', 'python']
#      - div_path('/home/chulsoo/test.txt')
#          - ['/home/chulsoo', 'test.txt']
#  - [참고] 리스트(l) 내에 새로운 정수값 (예를 들어 10)을 넣는 방법은 l.append(10) 이다.

# %%
k='/usr/local/bin/python'
def div_path(c):
    li=[k]
    a=len(c)
    b=c[::-1]
    spl=b.find('/')
    p=a-spl
    c=[c[:p]]
    c.append(k[p:])
    print (c)
    return c
div_path(k)
# Out:
# ['/usr/local/bin/', 'python']
# ['/usr/local/bin/', 'python']

# %% [markdown]
# 이 문제의 경우 먼저 len을 이용해 전체 문자열의 길이를 구하고, [::-1]을 이용해 문자열을 뒤에서 부터 바꾼 후 뒤에서 부터 /가 나오는 첫번째 '/'를 찾은 후 그 값을 전체 길이에 뺀다. 그 뺀 값이 경로명이 되고, 그 후 제외된 파일명을 리스트로 분리 하기 위해, append를 이용해 값을 불러와 2번째 리스트에 따로 저장해둔다.

# %% [markdown]
# ### 3. 두 개의 리스트를 인자로 받아서 그 두 개의 리스트에 대한 '합집합'을 반환하는 함수 list_union(lista, listb)를 작성하시오.
#  - 인자로 전달하는 리스트 2 개에는 정수값만 들어간다고 가정하자.
#  - 함수 내에서 새로운 리스트를 만들어 그 리스트 내에 인자로 받은 두 리스트의 모든 원소를 넣어 반환한다.
#  - 반환하는 리스트에는 절대로 중복된 원소가 들어 있으면 안된다 (집합의 조건).
#  - 반환하는 리스트는 정렬이 되어 있어야 한다.
#  - 다음과 같은 실행 및 출력 결과가 도출되어야 한다.
#     - list_union([1, 2, 3], [1, 2, 4])
#         - [1, 2, 3, 4]
#     - list_union([-10, -5, 0, -1], [100, 9, 0, 9])
#         - [-10, -5, -1, 0, 9, 100]
#     - list_union([0, 1, 2], [0, 1, 2])
#         - [0, 1, 2]
#  - [참고] 리스트(l) 내에 새로운 정수값 (예를 들어 10)을 넣는 방법은 l.append(10) 이다.
#  - [참고] 임의의 정수값 (x)이 리스트 (l) 내에 존재하는지 판단하는 방법은 x in l 이다.

# %%
def list_union(a,b):

    length = len(a)
    i=0
    while(length>i):
        if a[i] in b:
            a.remove(a[i])
            i-=1
            length-=1
        i=i+1
    c=a+b
    c.sort()
    print(c)
    
list_union([1,2,3],[1,2,4])
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# 이 문제는 def로 a,b 리스트를 받은 후, len을 이용해 길이를 받고, 그 값을 while을 이용해 돌리는 횟수를 정한 후, remove를 이용해 a[i]값을 본 후 그 값이 제거 할 값이면 제거하고, 아닐경우에는 제거를 하지 않도록 하여 값을 구한다. 이 때, remove함수는 바로바로 값을 없애주므로 리스트의 숫자도 줄어들기 때문에, i와 length또한 -1로 줄어준다.

# %% [markdown]
# ### 4. ACM-ICPC 문제 1110번]
#  - 더하기 사이클
#  - 0보다 크거나 같고, 99보다 작거나 같은 정수가 주어질 때 다음과 같은 연산을 할 수 있다. 먼저 주어진 수가 10보다 작다면 앞에 0을 붙여 두 자리 수로 만들고, 각 자리의 숫자를 더한다. 그 다음, 주어진 수의 가장 오른쪽 자리 숫자와 앞에서 구한 합의 가장 오른쪽 자리 숫자를 이어 붙이면 새로운 수를 만들 수 있다. 다음 예를 보자.
#     - 26부터 시작한다. 2+6 = 8이다. 새로운 숫자는 68이다. 6+8 = 14이다. 새로운 숫자는 84이다. 8+4 = 12이다. 새로운 숫자는 42이다. 4+2 = 6이다. 새로운 숫자는 26이다.
#     - 위의 예는 4번만에 원래 숫자로 돌아올 수 있다. 따라서 26의 사이클의 길이는 4이다.
#
#  - N이 주어졌을 때, N의 사이클의 길이를 구하는 프로그램을 작성하시오.

# %%
k=int(input())
count=0
result=k
while(k!=result or count==0):
    a=int(result/10)
    b=int(result%10)
    c=(a+b)%10
    a=b
    b=c
    result =a*10+b
    count+=1
print(count)
# Out:
# 26
# 4

# %% [markdown]
# 먼저 k로 값을 받는다. 그 후 while문으로 k가 result가 아닌경우 처음시작할때를 위해 count가 0일 때 돌아가는 함수로 만든다. 먼저 a와b를 /와 %로 각각의 숫자를 나누어준다. 그리고 그 값을 더해서 c값에 넣어서 %10을 이용해 값을 처리해 a=b,b=c로 하여 그 다음 새로운 숫자를 만들기 위해서 해준후, a*10+b를 해 새로운 함수로 만들어준 후 count를 이용해 몇번만에 성공한지를 세어준다.
# <img src="files/캡처.PNG">

# %% [markdown]
# ### 5. [Incremental Project] 웹 URL로 지정된 웹페이지를 문자열로 가져와 1) 모든 HTML 태그를 제외한 순수 텍스트 문자열만을 걸러내고, 2) 그 순수 텍스트 문자열 안에 존재하는 단어가 총 몇개인지 출력하는 프로그램을 작성하시오.
#
#  - HTML 태그는 다음 조건을 가지는 것이다.
#
#     - < 로 시작하여 >로 끝난다.
#     - 예를 들어, 아래와 같은 HTML 내용 내에 한 줄이 있다고 가정하자.
#     <label for="keep_signed">로그인 유지</label>
#     - 위 소스에서 HTML 태그를 제외한 순수 텍스트 문자열은 아래와 같다.
#     로그인 유지
#     - 한편, 아래와 같은 HTML 한 줄이 있다고 가정하자.
#     <link rel="stylesheet" href="/common/css/xe.min.css?20150910092654" />
#     - 위 소스는 HTML 태그로만 구성된 것이며 걸러낼 수 있는 순수 텍스 문자열은 존재하지 않는다.
#  - 단어를 나누는 기준은 오로지 공백문자 (whitespace)이다.
#
#     - 즉, 위 순수 텍스트 문자열인 "로그인 유지"에서 분리한 단어는 "로그인"과 "유지"이다.
#  - 중복을 고려하지 않고 무조건 모든 단어의 개수를 세어서 출력한다.
#  - 본 숙제를 위하여 HTML 파싱과 관련된 모듈 (예. BeautifulSoup) 사용 금지
#  - 다음은 URL로 지정된 웹페이지를 특정 문자열로 가져오는 코드이다.
#     - 즉, 숙제 코드는 아래 코드로 부터 시작해야 한다.

# %%
from urllib import request 
 
url = 'http://cse.koreatech.ac.kr'
f = request.urlopen(url)
source_bytes = f.read()
source = source_bytes.decode('utf-8')

# 추후 숙제 답안 제출 때엔 아래 코드는 주석처리할 것   
p=source.strip(' \t\n\r')
s=p.split('<')
result=[]

for x in s:
    length=len(x)
    b=x.find('>')
    if (b+1)!=length:
        key=x[b+1:length]
        result.append(key)
print(result)
a=' '.join(result)
print(a)
# Out:
# ['\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '컴퓨터공학부', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '!--', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n//', '\n', '\n', '\n', '\n', '\n', '\n', '\n\t\n\t', 'Schoolfun - Study and Fun', '\n\t\n\t\n\t\n\t\t\n\t\n\t\n\t\t', '\n\t\t\t\n', '\n', '\n', '\n\t', '\n\t\t', '\n\t\t\t', '\n\t\t\t\t', '\n\t\t\t\t', '\n\t\t\t\t', '\n\t\t\t', '\n\t\t\t', '\n\t\t\t', '\n\t\t\t\t', '!--\n\t\t\t\t', '\n\t\t\t\t\t', '\t\t\t\t\t', '\n\t\t\t\t', '\n\t\t\t\t-->\n\t\t\t\t', '\t\t\t\t\t\n\t\t\t\t\t', '\n\t', '로그인', '\n\t', '\n\t\t', '로그인', '\n\t\t', '\n\t\t', '\n\t\t', '\n\t\t\t\t', '\n\t\t\t', '아이디', '\t\t\t', '\t\t\t\t\t\t\t\t\t', '비밀번호', '\n\t\t\t', '\n\t\t\t', '\n\t\t\t\t', '\n\t\t\t\t', '로그인 유지', '\n\t\t\t', '\n\t\t\t', '브라우저를 닫더라도 로그인이 계속 유지될 수 있습니다. 로그인 유지 기능을 사용할 경우 다음 접속부터는 로그인할 필요가 없습니다. 단, 게임방, 학교 등 공공장소에서 이용 시 개인정보가 유출될 수 있으니 꼭 로그아
# ...

# %% [markdown]
# 먼저 split을 이용해 <가 들어간 문자열들을 모두 리스트로 만든 후, for문을 이용해 각각의 리스트에 대해서 분리하기 위해서 길이(len)와 find(>)인 함수를 이용한다. 그 후 if 문으로 len과 find를 비교해 값이 다를 경우 find부터 len까지의 문자열을 출력하여 그 문자열이 순수 텍스트 문자열이다. 그러나, 실행하면서 이스케이프 문자가 있어서, 실행에 실패하였다.
